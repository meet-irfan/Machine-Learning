# %%
# Import the library with an alias 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the Titanic dataset from a CSV file and store it in a DataFrame named 
titanic_data = pd.read_csv("titanic.csv")
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Drop columns 'PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked' from the DataFrame 'df'
# The 'inplace=True' parameter modifies the original DataFrame instead of creating a new one
titanic_data.drop(["PassengerId","Name","Ticket","Cabin","Parch"],axis="columns",inplace=True)

# %%
# Create dummy variables for the 'Sex' column using one-hot encoding
titanic_data.replace({'Sex':{'male':0,'female':1},'Embarked':{'S':1,'Q':2,'C':3}},inplace =True)
titanic_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp     Fare  Embarked
# 0           0       3    0  22.0      1   7.2500       1.0
# 1           1       1    1  38.0      1  71.2833       3.0
# 2           1       3    1  26.0      0   7.9250       1.0
# 3           1       1    1  35.0      1  53.1000       1.0
# 4           0       3    0  35.0      0   8.0500       1.0
# ..        ...     ...  ...   ...    ...      ...       ...
# 886         0       2    0  27.0      0  13.0000       1.0
# 887         1       1    1  19.0      0  30.0000       1.0
# 888         0       3    1   NaN      1  23.4500       1.0
# 889         1       1    0  26.0      0  30.0000       3.0
# 890         0       3    0  32.0      0   7.7500       2.0
#
# [891 rows x 7 columns]

# %%
titanic_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp     Fare  Embarked
# 0           0       3    0  22.0      1   7.2500       1.0
# 1           1       1    1  38.0      1  71.2833       3.0
# 2           1       3    1  26.0      0   7.9250       1.0
# 3           1       1    1  35.0      1  53.1000       1.0
# 4           0       3    0  35.0      0   8.0500       1.0
# ..        ...     ...  ...   ...    ...      ...       ...
# 886         0       2    0  27.0      0  13.0000       1.0
# 887         1       1    1  19.0      0  30.0000       1.0
# 888         0       3    1   NaN      1  23.4500       1.0
# 889         1       1    0  26.0      0  30.0000       3.0
# 890         0       3    0  32.0      0   7.7500       2.0
#
# [891 rows x 7 columns]

# %%
# Create a new DataFrame 'inputs' excluding the 'Survived' column
inputs = titanic_data.drop(["Survived"],axis=1)
inputs
# Out:
#      Pclass  Sex   Age  SibSp     Fare  Embarked
# 0         3    0  22.0      1   7.2500       1.0
# 1         1    1  38.0      1  71.2833       3.0
# 2         3    1  26.0      0   7.9250       1.0
# 3         1    1  35.0      1  53.1000       1.0
# 4         3    0  35.0      0   8.0500       1.0
# ..      ...  ...   ...    ...      ...       ...
# 886       2    0  27.0      0  13.0000       1.0
# 887       1    1  19.0      0  30.0000       1.0
# 888       3    1   NaN      1  23.4500       1.0
# 889       1    0  26.0      0  30.0000       3.0
# 890       3    0  32.0      0   7.7500       2.0
#
# [891 rows x 6 columns]

# %%
# Create a Series 'target' containing the 'Survived' column
outputs = titanic_data['Survived']
outputs
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
titanic_data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Fare          0
# Embarked      2
# dtype: int64
